# %% [markdown]
# <div style="background-color: #1a1a1a; border-top: 2px solid #ff0055; border-right: 2px solid #ff0055; padding: 25px; font-family: 'Segoe UI', Tahoma, sans-serif; color: #e0e0e0; position: relative; border-radius: 0px 40px 0px 40px; box-shadow: 10px 10px 0px rgba(255,0,85,0.05); margin-bottom: 20px;">
#     <div style="position: absolute; top: 10px; right: 25px; color: #ff0055; font-family: monospace; font-size: 0.75em; letter-spacing: 1px;">
#         CORE_DOC // 001
#     </div>
#     <span style="color: #ff0055; font-family: monospace; font-weight: bold;">[  TERMINOLOGY ]</span>
#     <h1 style="color: #ffffff; margin: 10px 0; font-family: 'Courier New'; text-transform: uppercase;">WHAT IS YOLO?</h1>
#     <div style="background: linear-gradient(90deg, #ff0055, transparent); height: 1px; width: 80%; margin-bottom: 15px;"></div>
#     <p style="line-height: 1.6; color: #bbb;">
#         <b>YOLO</b> (You Only Look Once) is a high-speed deep learning architecture. Unlike older models that scan an image multiple times, YOLO looks at the entire image in a <b>single forward pass</b>.
#     </p>
#     <ul style="list-style-type: square; color: #ff0055; font-family: monospace; font-size: 0.9em;">
#         <li><span style="color: #eee;">IDENTIFIES: Object Class (What it is)</span></li>
#         <li><span style="color: #eee;">LOCALIZES: Bounding Box (Where it is)</span></li>
#     </ul>
# </div>

# %% [markdown]
# <div style="background-color: #1a1a1a; border-left: 10px solid #00d4ff; padding: 20px; font-family: 'Courier New', monospace; color: #e0e0e0; border-radius: 0px 40px 0px 40px; position: relative; border: 1px solid #333; border-left: 10px solid #00d4ff;">
#     <div style="position: absolute; top: 10px; right: 25px; color: #00d4ff; font-weight: bold; font-size: 0.8em;">
#         IMPORT // SUCCESS
#     </div>
#     <span style="color: #00d4ff; font-size: 1.1em;">[ DEPENDENCY_LOADED ]</span>
#     <h1 style="color: #ffffff; margin: 5px 0; letter-spacing: 2px;">ULTRALYTICS_ENGINE</h1>
#     <p style="margin: 0; color: #888;">PURPOSE: Accessing YOLOv8/v11 Pre-trained Weights</p>
# </div>

# %%
pip install ultralytics

# %% [markdown]
# <div style="background-color: #1a1a1a;
#             border-left: 10px solid #00ff41;
#             padding: 20px;
#             font-family: 'Courier New', Courier, monospace;
#             color: #00ff41;
#             position: relative;
#             border-radius: 0px 40px 0px 40px;
#             border: 1px solid #333;
#             box-shadow: 0 0 15px rgba(0,255,65,0.1);">
#     <div style="position: absolute; top: 10px; right: 25px; color: #00ff41; font-weight: bold; font-size: 0.8em;">
#         PKG_MGR // PIP
#     </div>
#     <span style="color: #00ff41; font-size: 1.1em;">[ SYSTEM_PROVISIONING ]</span>
#     <h1 style="color: #ffffff; margin: 5px 0; letter-spacing: 1px;">INSTALLING_ULTRALYTICS</h1>
#     <p style="margin: 0; color: #008f11; font-size: 0.9em;">RESOURCES: YOLOv8 / YOLOv11 / RT-DETR</p>
# </div>

# %%
# Load YOLOv8 model (auto-downloads)
# YOLO("yolov8n.pt")  # Fastest  n=nano
# YOLO("yolov8s.pt")  # Balanced s=small
# YOLO("yolov8m.pt")  # Better accuracy m=medium
# YOLO("yolov8l.pt")  # High accuracy l=large

# %% [markdown]
# <div style="background-color: #1a1a1a;
#             border-top: 2px solid #ffcc00;
#             border-right: 2px solid #ffcc00;
#             padding: 20px;
#             font-family: 'Courier New', Courier, monospace;
#             color: #e0e0e0;
#             position: relative;
#             border-radius: 40px 0px 40px 0px;
#             box-shadow: 10px 10px 0px rgba(255,204,0,0.05);">
#     <div style="position: absolute; top: 10px; right: 25px; color: #ffcc00; font-family: sans-serif; font-size: 0.7em;">
#         SELECT_WEIGHTS // V8.0
#     </div>
#     <span style="color: #ffcc00; font-size: 1.2em;">[ RESOURCE_ALLOCATION ]</span>
#     <h1 style="color: #ffffff; margin: 10px 0; text-transform: uppercase;">YOLOv8_Weight_Matrix</h1>
#     <div style="background: #333; height: 1px; width: 100%; margin-bottom: 15px;"></div>
#     <div style="display: flex; flex-direction: column; gap: 8px; font-size: 0.9em;">
#         <div><span style="color: #00ff41;">● NANO:</span> <code style="color: #eee;">yolov8n.pt</code> <span style="color: #666;">(Fastest / Mobile-Ready)</span></div>
#         <div><span style="color: #00d4ff;">● SMALL:</span> <code style="color: #eee;">yolov8s.pt</code> <span style="color: #666;">(Optimized / Balanced)</span></div>
#         <div><span style="color: #ffcc00;">● MEDIUM:</span> <code style="color: #eee;">yolov8m.pt</code> <span style="color: #666;">(High Precision)</span></div>
#         <div><span style="color: #ff0055;">● LARGE:</span> <code style="color: #eee;">yolov8l.pt</code> <span style="color: #666;">(Heavy / Research Grade)</span></div>
#     </div>
# </div>

# %%
from ultralytics import YOLO #YOLO Importing
import cv2 #computer_vision  
"""object detect list:[ 0-person, 1-bicycle, 2-car, 3-motorcycle, 4-airplane, 5-bus, 6-train, 7-truck, 8-boat, 9-traffic light,
10-fire hydrant, 11-stop sign, 12-parking meter, 13-bench, 14-bird, 15-cat, 16-dog, 17-horse, 18-sheep, 19-cow,
20-elephant, 21-bear, 22-zebra, 23-giraffe, 24-backpack, 25-umbrella, 26-handbag, 27-tie, 28-suitcase, 29-frisbee,
30-skis, 31-snowboard, 32-sports ball, 33-kite, 34-baseball bat, 35-baseball glove, 36-skateboard, 37-surfboard, 38-tennis racket, 39-bottle,
40-wine glass, 41-cup, 42-fork, 43-knife, 44-spoon, 45-bowl, 46-banana, 47-apple, 48-sandwich, 49-orange,
50-broccoli, 51-carrot, 52-hot dog, 53-pizza, 54-donut, 55-cake, 56-chair, 57-couch, 58-potted plant, 59-bed,
60-dining table, 61-toilet, 62-tv, 63-laptop, 64-mouse, 65-remote, 66-keyboard, 67-cell phone, 68-microwave, 69-oven,
70-toaster, 71-sink, 72-refrigerator, 73-book, 74-clock, 75-vase, 76-scissors, 77-teddy bear, 78-hair drier, 79-toothbrush ]"""

model = YOLO("yolov8n.pt")  # pretrained model  # YOLO("yolov8n.pt")  # Fastest 

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    
    results = model(frame)

    annotated_frame = results[0].plot()

    cv2.imshow("YOLO Detection", annotated_frame)

    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
#
# 0: 480x640 1 person, 279.2ms
# Speed: 34.2ms preprocess, 279.2ms inference, 20.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 169.3ms
# Speed: 5.6ms preprocess, 169.3ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 143.1ms
# Speed: 4.0ms preprocess, 143.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 157.7ms
# Speed: 5.1ms preprocess, 157.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 155.4ms
# Speed: 3.6ms preprocess, 155.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 167.5ms
# Speed: 5.5ms preprocess, 167.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 refrigerator, 155.0ms
# Speed: 5.2ms preprocess, 155.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %% [markdown]
# <div style="background-color: #1a1a1a;
#             border-top: 2px solid #00ff41;
#             border-right: 2px solid #00ff41;
#             padding: 25px;
#             font-family: 'Courier New', Courier, monospace;
#             color: #e0e0e0;
#             position: relative;
#             border-radius: 40px 0px 40px 0px;
#             box-shadow: 10px 10px 0px rgba(0,255,65,0.05);">
#     <div style="position: absolute; top: 10px; right: 25px; color: #00ff41; font-family: sans-serif; font-size: 0.7em;">
#         FIELD_DEPLOYMENT // ACTIVE
#     </div>
#     <span style="color: #00ff41; font-size: 1.2em;">[ TARGET_SCENARIOS ]</span>
#     <h1 style="color: #ffffff; margin: 10px 0; text-transform: uppercase; letter-spacing: 2px;">REAL_WORLD_UTILITY</h1>
#     <div style="background: linear-gradient(90deg, #00ff41, transparent); height: 1px; width: 100%; margin-bottom: 20px;"></div>
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 15px; font-size: 0.9em;">
#         <div style="border-left: 3px solid #333; padding-left: 10px;">
#             <b style="color: #00ff41;">01. SECURITY:</b> CCTV Surveillance & Intrusion Detection.
#         </div>
#         <div style="border-left: 3px solid #333; padding-left: 10px;">
#             <b style="color: #00ff41;">02. AUTONOMY:</b> Self-Driving Cars & Obstacle Avoidance.
#         </div>
#         <div style="border-left: 3px solid #333; padding-left: 10px;">
#             <b style="color: #00ff41;">03. IDENTITY:</b> High-Precision Face Detection & Recognition.
#         </div>
#         <div style="border-left: 3px solid #333; padding-left: 10px;">
#             <b style="color: #00ff41;">04. ANALYTICS:</b> Retail Traffic & People Counting.
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="background-color: #1a1a1a;
#             border-bottom: 5px solid #00ff41;
#             padding: 30px;
#             font-family: 'Courier New', Courier, monospace;
#             color: #e0e0e0;
#             text-align: center;
#             border-radius: 40px 40px 0px 0px;
#             position: relative;
#             border: 1px solid #333;">
#     <div style="color: #00ff41; font-size: 1.5em; margin-bottom: 10px;">
#         <span style="animation: blink 1s infinite;">[✓]</span> SESSION_COMPLETE
#     </div>
#     <h1 style="color: #ffffff; margin: 0; letter-spacing: 3px;">THANK YOU</h1>
#     <p style="color: #666; margin-top: 10px; font-size: 0.9em;">
#         YOLOv8 Engine Standby... All processes successfully executed.
#     </p>
#     <div style="margin-top: 20px; font-size: 0.8em; color: #444;">
#         // USER: SHARMA_DEV // NODE: LOCAL_HOST // 2026
#     </div>
# </div>
#
# <style>
# @keyframes blink { 0% { opacity: 1; } 50% { opacity: 0; } 100% { opacity: 1; } }
# </style>
