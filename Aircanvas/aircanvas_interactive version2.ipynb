# %% [markdown]
# <div style="text-align:center; background-color:#1e293b; padding:20px; border-radius:10px;">
#   <h1 style="font-family: 'Times New Roman', Times, serif; margin:0;">
#     <b style="color:white;">Codroid </b>
#     <span style="color:#38bdf8;"><b>Hub </b></span>
#     <b style="color:white;">Pvt Ltd</b>
#   </h1>
# </div>

# %% [markdown]
# <div style="background: #0d1117;
#             border: 1px solid #30363d;
#             border-left: 5px solid #58a6ff;
#             border-radius: 12px;
#             padding: 30px 20px;
#             text-align: center;
#             font-family: 'SFMono-Regular', Consolas, 'Liberation Mono', Menlo, monospace;
#             box-shadow: 0 10px 40px rgba(0,0,0,0.6);
#             margin-bottom: 10px;
#             position: relative;
#             overflow: hidden;">
#
#   <div style="position: absolute; top: 0; left: 0; width: 100%; height: 2px;
#               background: linear-gradient(90deg, transparent, #58a6ff, transparent);
#               opacity: 0.5;"></div>
#
#   <h1 style="font-size: 3.5em; font-weight: 900; margin: 0; letter-spacing: -2px;
#              background: linear-gradient(to right, #58a6ff, #bc8cff);
#              -webkit-background-clip: text; -webkit-text-fill-color: transparent;
#              text-transform: uppercase;">
#     Air_Canvas
#   </h1>
#
#   <p style="color: #8b949e; font-size: 1.1em; margin: 15px 0 25px; font-weight: 300; letter-spacing: 1px;">
#     [ STATUS: <span style="color: #3fb950;">ACTIVE</span> ] Gesture-to-Digital Interface
#   </p>
#
#   <div style="display: flex; justify-content: center; gap: 12px; flex-wrap: wrap;">
#     <span style="background: rgba(88, 166, 255, 0.1); color: #58a6ff;
#                 border: 1px solid rgba(88, 166, 255, 0.3); border-radius: 4px;
#                 padding: 4px 12px; font-size: 0.8em; text-transform: uppercase;">
#       &gt; cv_engine
#     </span>
#     <span style="background: rgba(188, 140, 255, 0.1); color: #bc8cff;
#                 border: 1px solid rgba(188, 140, 255, 0.3); border-radius: 4px;
#                 padding: 4px 12px; font-size: 0.8em; text-transform: uppercase;">
#       &gt; neural_tracking
#     </span>
#     <span style="background: rgba(63, 185, 80, 0.1); color: #3fb950;
#                 border: 1px solid rgba(63, 185, 80, 0.3); border-radius: 4px;
#                 padding: 4px 12px; font-size: 0.8em; text-transform: uppercase;">
#       &gt; low_latency_ai
#     </span>
#   </div>
#
#   <div style="margin-top: 30px; border-top: 1px dashed #30363d; padding-top: 20px;">
#     <p style="color:#7d8590; font-size: 0.85em;">
#       DEPENDENCIES: Python 3.x // OpenCV // MediaPipe // NumPy
#     </p>
#   </div>
# </div>

# %% [markdown]
# <div style="background: #0d1117;
#             border: 1px solid #30363d;
#             border-radius: 12px;
#             padding: 40px;
#             font-family: 'SFMono-Regular', Consolas, 'Liberation Mono', Menlo, monospace;
#             box-shadow: 0 10px 40px rgba(0,0,0,0.6);
#             margin-bottom: 10px;
#             position: relative;">
#
#   <div style="background: #161b22;
#               border: 1px solid #30363d;
#               border-left: 4px solid #58a6ff;
#               border-radius: 8px;
#               padding: 25px 30px;
#               margin-bottom: 25px;">
#     <h2 style="color: #58a6ff; margin-top: 0; font-size: 1.4em; text-transform: uppercase; letter-spacing: 2px;">
#       // Problem_Statement
#     </h2>
#     <p style="color: #c9d1d9; font-size: 1.05em; line-height: 1.6;">
#       Traditional interaction requires physical hardware peripherals (stylus, touchscreens).
#       How do we bridge the gap between <span style="color: #bc8cff;">physical motion</span> and <span style="color: #bc8cff;">digital rendering</span>?
#     </p>
#     <p style="color: #8b949e; font-size: 0.95em; line-height: 1.6; border-top: 1px solid #30363d; pt: 15px; margin-top: 15px; padding-top: 15px;">
#       Objective: Architect a <strong style="color:#58a6ff">Zero-Contact Interface</strong> capable of real-time spatial coordinate mapping.
#       The system must parse hand landmarks to execute draw/erase operations via standard optical sensors.
#     </p>
#   </div>
#
#   <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#     <div style="background: rgba(248, 113, 113, 0.05);
#                 border: 1px solid rgba(248, 113, 113, 0.2);
#                 border-radius: 8px;
#                 padding: 20px;
#                 position: relative;">
#       <h3 style="color: #f87171; margin: 0 0 10px 0; font-size: 1em; text-transform: uppercase;">
#         [!] Logic_Constraints
#       </h3>
#       <p style="color: #8b949e; font-size: 0.85em; line-height: 1.6; margin: 0;">
#         Optimizing landmark stability under varying luminosity, reducing frame-processing jitter,
#         and implementing robust gesture-state classification.
#       </p>
#     </div>
#     <div style="background: rgba(52, 211, 153, 0.05);
#                 border: 1px solid rgba(52, 211, 153, 0.2);
#                 border-radius: 8px;
#                 padding: 20px;">
#       <h3 style="color: #34d399; margin: 0 0 10px 0; font-size: 1em; text-transform: uppercase;">
#         [*] Expected_Output
#       </h3>
#       <p style="color: #8b949e; font-size: 0.85em; line-height: 1.6; margin: 0;">
#         A low-latency HUD (Heads-Up Display) allowing multi-color stroke persistence and
#         dynamic canvas clearing with &lt;30ms processing overhead.
#       </p>
#     </div>
#
#   </div>
#
#   <div style="text-align: right; margin-top: 20px;">
#     <span style="color: #30363d; font-size: 0.75em;">SYS_ANALYSIS_COMPLETE // 2026</span>
#   </div>
# </div>

# %% [markdown]
# <div style="background: #0d1117;
#             border: 1px solid #30363d;
#             border-radius: 12px;
#             padding: 40px;
#             font-family: 'SFMono-Regular', Consolas, 'Liberation Mono', Menlo, monospace;
#             box-shadow: 0 10px 40px rgba(0,0,0,0.6);
#             margin-bottom: 10px;">
#
#   <div style="background: rgba(63, 185, 80, 0.05);
#               border: 1px solid rgba(63, 185, 80, 0.3);
#               border-left: 4px solid #3fb950;
#               border-radius: 8px;
#               padding: 25px 30px;
#               margin-bottom: 25px;">
#     <h2 style="color: #3fb950; margin-top: 0; font-size: 1.4em; text-transform: uppercase; letter-spacing: 2px;">
#       // Final_Implementation
#     </h2>
#     <p style="color: #c9d1d9; font-size: 1.05em; line-height: 1.6;">
#       Integrated <span style="color: #58a6ff;">MediaPipe Neural Hand Pipeline</span> with
#       <span style="color: #58a6ff;">OpenCV Matrix Rendering</span>.
#       The solution operates as a high-frequency event loop processing real-time video telemetry.
#     </p>
#   </div>
#
#   <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 15px; margin-bottom: 25px;">
#     <div style="background: #161b22; border: 1px solid #30363d; border-radius: 8px; padding: 15px; text-align: center;">
#       <div style="color: #58a6ff; font-size: 0.8em; margin-bottom: 10px;">[01_INPUT]</div>
#       <h4 style="color: #f0f6fc; margin: 0 0 8px; font-size: 0.9em;">FRAME_CAPTURE</h4>
#       <p style="color: #8b949e; font-size: 0.75em; line-height: 1.4;">Mirror-flipped RGB stream extraction</p>
#     </div>
#     <div style="background: #161b22; border: 1px solid #30363d; border-radius: 8px; padding: 15px; text-align: center;">
#       <div style="color: #bc8cff; font-size: 0.8em; margin-bottom: 10px;">[02_INFERENCE]</div>
#       <h4 style="color: #f0f6fc; margin: 0 0 8px; font-size: 0.9em;">LANDMARK_MAP</h4>
#       <p style="color: #8b949e; font-size: 0.75em; line-height: 1.4;">21-point coordinate triangulation</p>
#     </div>
#     <div style="background: #161b22; border: 1px solid #30363d; border-radius: 8px; padding: 15px; text-align: center;">
#       <div style="color: #34d399; font-size: 0.8em; margin-bottom: 10px;">[03_LOGIC]</div>
#       <h4 style="color: #f0f6fc; margin: 0 0 8px; font-size: 0.9em;">EVENT_TRIGGER</h4>
#       <p style="color: #8b949e; font-size: 0.75em; line-height: 1.4;">Gesture-to-command state switching</p>
#     </div>
#   </div>
#
#   <div style="background: #0d1117; border: 1px solid #30363d; border-radius: 8px; overflow: hidden;">
#     <div style="background: #161b22; padding: 12px 20px; border-bottom: 1px solid #30363d;">
#       <h3 style="color: #7d8590; margin: 0; font-size: 0.9em; text-transform: uppercase; letter-spacing: 1px;">
#         &gt;_ Gesture_Key_Bindings
#       </h3>
#     </div>
#     <table style="width: 100%; border-collapse: collapse; color: #c9d1d9; font-size: 0.85em;">
#       <thead>
#         <tr style="text-align: left; background: rgba(48, 54, 61, 0.2);">
#           <th style="padding: 12px 20px; color: #8b949e; font-weight: 400;">INPUT_STATE</th>
#           <th style="padding: 12px 20px; color: #8b949e; font-weight: 400;">FUNCTION_CALL</th>
#         </tr>
#       </thead>
#       <tbody>
#         <tr style="border-bottom: 1px solid #21262d;">
#           <td style="padding: 12px 20px;">INDEX_UP</td>
#           <td style="padding: 12px 20px; color: #58a6ff;">canvas.draw_stroke()</td>
#         </tr>
#         <tr style="border-bottom: 1px solid #21262d;">
#           <td style="padding: 12px 20px;">INDEX + MIDDLE_UP</td>
#           <td style="padding: 12px 20px; color: #bc8cff;">ui.select_color()</td>
#         </tr>
#         <tr style="border-bottom: 1px solid #21262d;">
#           <td style="padding: 12px 20px;">THUMB_ONLY</td>
#           <td style="padding: 12px 20px; color: #f87171;">canvas.set_eraser()</td>
#         </tr>
#         <tr>
#           <td style="padding: 12px 20px;">ALL_EXTENDED</td>
#           <td style="padding: 12px 20px; color: #f97316;">canvas.flush_memory()</td>
#         </tr>
#       </tbody>
#     </table>
#   </div>
# </div>

# %% [markdown]
# <div style="background: #0f172a; border-radius: 14px; padding: 25px; border: 1px solid #1e293b; margin-bottom: 20px;">
#     <h3 style="color: #94a3b8; margin-top: 0; font-size: 1em; letter-spacing: 0.1em; text-transform: uppercase;">Prerequisites</h3>
#     <div style="background: #020617; border-radius: 8px; padding: 15px; font-family: monospace; color: #4ade80; font-size: 0.9em; line-height: 1.8;">
#         <ol>
#       <li>pip install opencv-python 4.13.0</li>
#       <li>pip install  mediapipe 0.10.9</li>
#       <li>pip install  numpy 2.4.4</li>
#         </ol>
#   </div>

# %%
import cv2
import numpy as np
import mediapipe as mp
import time

# %% [markdown]
# <div style="font-family:'Segoe UI',sans-serif; background:#1e293b;
#      border-radius:10px; padding:14px 20px; margin-bottom:5px; border-left:4px solid #60a5fa;">
#   <span style="color:#60a5fa; font-weight:700;">📝 Version 1.0</span>
#   <!-- <span style="color:#94a3b8; font-size:0.9em; margin-left:12px;">Base version — full 1280×720 with save, clear &amp; undo</span> -->
# </div>

# %%
# ---------- CONFIG ----------
WIDTH, HEIGHT = 640, 480 #To change system configrations 
CONFIDENCE = 0.7

tool = "BRUSH"
colors = [(255,0,255),(0,255,0),(255,255,0),(0,0,255)]
color_ptr = 0
brush_thickness = 8

# ---------- MEDIAPIPE ----------
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(
    max_num_hands=1,
    model_complexity=0,
    min_detection_confidence=CONFIDENCE,
    min_tracking_confidence=CONFIDENCE
)

# ---------- VARIABLES ----------
canvas = np.zeros((HEIGHT, WIDTH, 3), dtype=np.uint8)
xp, yp = 0, 0
cloc_x, cloc_y = 0, 0
prev_time = 0

# ---------- CAMERA ----------
cap = cv2.VideoCapture(0)
cap.set(3, WIDTH)
cap.set(4, HEIGHT)

# %% [markdown]
# <div style="font-family:'Segoe UI',sans-serif; background:#1e293b;
#      border-radius:10px; padding:14px 20px; margin-bottom:5px; border-left:4px solid #60a5fa;">
#   <span style="color:#60a5fa; font-weight:700;">📝 HAND Connections</span>
#     <span style="color:#94a3b8; font-size:0.9em; margin-left:12px;"> skeleton of hand </span>
# </div>

# %%
# ---------- HAND CONNECTIONS ----------
connections = [
    (0,1),(1,2),(2,3),(3,4),
    (0,5),(5,6),(6,7),(7,8),
    (0,9),(9,10),(10,11),(11,12),
    (0,13),(13,14),(14,15),(15,16),
    (0,17),(17,18),(18,19),(19,20)
]
# skeleton of hand

# %% [markdown]
# <div style="font-family:'Segoe UI',sans-serif; background:#1e293b;
#      border-radius:10px; padding:14px 20px; margin-bottom:5px; border-left:4px solid #60a5fa;">
#   <span style="color:#60a5fa; font-weight:700;">Functions of Code</span>
#     <span style="color:#94a3b8; font-size:0.9em; margin-left:12px;"></span>
# </div>

# %%
# ---------- FUNCTIONS ----------
def get_fingers(lm):
    fingers = []
    fingers.append(lm[4].x < lm[3].x)
    for tip in [8,12,16,20]:
        fingers.append(lm[tip].y < lm[tip-2].y)
    return fingers

def draw_skeleton(img, lm):
    points = []
    for p in lm:
        x = int(p.x * WIDTH)
        y = int(p.y * HEIGHT)
        points.append((x,y))

    for c in connections:
        cv2.line(img, points[c[0]], points[c[1]], (0,255,255), 2)

    for i in [0,4,8,12,16,20]:
        cv2.circle(img, points[i], 5, (0,255,0), -1)

def draw_ui(bg):
    cv2.rectangle(bg, (0,0), (WIDTH,60), (30,30,30), -1)
    cv2.putText(bg, f"{tool}", (10,40),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2)

    for i, col in enumerate(colors):
        thickness = 6 if i == color_ptr else 2
        cv2.rectangle(bg, (150+i*70,10), (210+i*70,50), col, -1)
        cv2.rectangle(bg, (150+i*70,10), (210+i*70,50), (255,255,255), thickness)

def handle_buttons(x,y):
    global color_ptr
    if y < 60:
        for i in range(4):
            if 150+i*70 < x < 210+i*70:
                color_ptr = i

# %% [markdown]
# <div style="font-family:'Segoe UI',sans-serif; background:#1e293b;
#      border-radius:10px; padding:14px 20px; margin-bottom:5px; border-left:4px solid #60a5fa;">
#   <span style="color:#60a5fa; font-weight:700;">Main loop</span>
#     <span style="color:#94a3b8; font-size:0.9em; margin-left:12px;"> </span>

# %%
# ---------- MAIN LOOP ----------
while True:
    success, frame = cap.read()
    if not success:
        break

    frame = cv2.flip(frame,1)

    # Reduce size for faster processing
    small = cv2.resize(frame, (0,0), fx=0.5, fy=0.5)
    rgb = cv2.cvtColor(small, cv2.COLOR_BGR2RGB)
    result = hands.process(rgb)

    bg = np.zeros((HEIGHT, WIDTH, 3), dtype=np.uint8)
    draw_ui(bg)

    if result.multi_hand_landmarks:
        for hand_lms in result.multi_hand_landmarks:
            lm = hand_lms.landmark

            draw_skeleton(bg, lm)

            x = int(lm[8].x * WIDTH)
            y = int(lm[8].y * HEIGHT)

            cloc_x += (x - cloc_x) / 2
            cloc_y += (y - cloc_y) / 2

            fingers = get_fingers(lm)

            # All fingers → clear canvas
            if all(fingers):
                canvas[:] = 0

            # Thumb only → eraser
            elif fingers[0] and not any(fingers[1:]):
                tool = "ERASER"

            # Two fingers → select color
            elif fingers[1] and fingers[2]:
                xp, yp = 0, 0
                handle_buttons(int(cloc_x), int(cloc_y))
                tool = "BRUSH"

            # One finger → draw
            elif fingers[1] and not any(fingers[2:]):
                if xp == 0 and yp == 0:
                    xp, yp = cloc_x, cloc_y

                color = (0,0,0) if tool=="ERASER" else colors[color_ptr]
                thickness = 25 if tool=="ERASER" else brush_thickness

                cv2.line(canvas,
                         (int(xp), int(yp)),
                         (int(cloc_x), int(cloc_y)),
                         color, thickness)

                xp, yp = cloc_x, cloc_y
            else:
                xp, yp = 0, 0

    # FPS Calculation
    curr = time.time()
    fps = 1/(curr-prev_time) if prev_time!=0 else 0
    prev_time = curr

    cv2.putText(bg,f'FPS:{int(fps)}',(10,HEIGHT-10),
                cv2.FONT_HERSHEY_SIMPLEX,0.7,(0,255,0),2)

    # Merge drawing + UI
    output = cv2.addWeighted(bg,1,canvas,1,0)

    # 🔥 MINI CAMERA VIEW
    small_cam = cv2.resize(frame, (200,150))
    output[HEIGHT-150:HEIGHT, WIDTH-200:WIDTH] = small_cam

    cv2.rectangle(output,
                  (WIDTH-200, HEIGHT-150),
                  (WIDTH, HEIGHT),
                  (255,255,255), 2)

    cv2.imshow("Air Canvas + Skeleton", output)

    key = cv2.waitKey(1)
    if key == 27 or key == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# <!-- <div style="font-family: 'Segoe UI', sans-serif; max-width: 900px; margin: 0 auto;"> -->
# <div  style="background: linear-gradient(135deg, #0f0c29, #302b63, #24243e);
#      border-radius: 20px; padding: 50px 40px; text-align: center;
#      font-family: 'Segoe UI', sans-serif; box-shadow: 0 8px 32px rgba(0,0,0,0.5);
#      margin-bottom: 10px;">
#
#
#   <h2 style="color: #f1f5f9; font-size: 1.8em; margin-bottom: 20px;">🖥️ Program Output</h2>
#     <p style="color: #64748b; font-size: 0.85em; text-align: center; margin: 0;">
#       ↑ Simulated preview of the Air Canvas window — your actual drawings appear here in real time
#     </p>
#        <div style="text-align:center;">
#   <img src="image.png" width="1000"
#        style="border:3px solid #38bdf8; border-radius:10px; padding:5px;">
# </div>
#   </div>
#   <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 12px;">
#     <div style="background: #1e293b; border-radius: 10px; padding: 15px; text-align: center;">
#       <div style="font-size: 1.8em;">⚡</div>
#       <p style="color: #60a5fa; font-weight: 700; font-size: 1.2em; margin: 5px 0;">30–60 FPS</p>
#       <p style="color: #64748b; font-size: 0.8em; margin: 0;">Real-time performance</p>
#     </div>
#     <div style="background: #1e293b; border-radius: 10px; padding: 15px; text-align: center;">
#       <div style="font-size: 1.8em;">🎯</div>
#       <p style="color: #a78bfa; font-weight: 700; font-size: 1.2em; margin: 5px 0;">21 Landmarks</p>
#       <p style="color: #64748b; font-size: 0.8em; margin: 0;">Hand keypoints tracked</p>
#     </div>
#     <div style="background: #1e293b; border-radius: 10px; padding: 15px; text-align: center;">
#       <div style="font-size: 1.8em;">🎨</div>
#       <p style="color: #34d399; font-weight: 700; font-size: 1.2em; margin: 5px 0;">4 Colours</p>
#       <p style="color: #64748b; font-size: 0.8em; margin: 0;">Selectable via gesture</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="font-family: 'Segoe UI', sans-serif; text-align: center;
#      background: linear-gradient(135deg, #0f172a, #1e293b);
#      border-radius: 16px; padding: 35px 40px; border: 1px solid #334155;">
#
#   <div style="font-size: 2em; margin-bottom: 10px;"></div>
#   <h2 style="color: #f1f5f9; margin: 0 0 8px;">Thanks for Exploring Air Canvas!</h2>
#   <p style="color: #64748b; font-size: 0.9em; margin: 0 0 20px;">
#     A gesture-controlled drawing app built with Python, OpenCV &amp; MediaPipe
#   </p>
#
#   <div style="display: flex; justify-content: center; gap: 12px; flex-wrap: wrap;">
#     <span style="background: #1e293b; color: #60a5fa; border-radius: 20px;
#           padding: 8px 20px; font-size: 0.85em;">Python 3.11</span>
#     <span style="background: #1e293b; color: #a78bfa; border-radius: 20px;
#           padding: 8px 20px; font-size: 0.85em;">OpenCV</span>
#     <span style="background: #1e293b; color: #34d399; border-radius: 20px;
#           padding: 8px 20px; font-size: 0.85em;">MediaPipe</span>
#     <span style="background: #1e293b; color: #fbbf24; border-radius: 20px;
#           padding: 8px 20px; font-size: 0.85em;">NumPy</span>
#   </div>
# </div>
